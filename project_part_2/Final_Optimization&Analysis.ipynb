# %%
import os
import matplotlib.pyplot as plt
import cv2

# Path to training results
TRAIN_DIR = "/kaggle/input/dl-project/runs/detect/car_damage_7cls_final"

def show_result_plot(filename, title):
    path = os.path.join(TRAIN_DIR, filename)
    if os.path.exists(path):
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        plt.figure(figsize=(12, 8))
        plt.imshow(img)
        plt.axis("off")
        plt.title(title, fontsize=14, fontweight='bold')
        plt.show()
    else:
        print(f"File not found: {path}")

# 1. Training Progress Metrics
print("Displaying Training Metrics...")
show_result_plot("results.png", "Training Metrics: Loss and mAP Curves")

# 2. Confusion Matrix Analysis
print("Displaying Confusion Matrix...")
show_result_plot("confusion_matrix.png", "Confusion Matrix: Class-wise Accuracy")

# 3.  F1 Curve 
print("Displaying  F1 Curve...")
show_result_plot("BoxF1_curve.png", "F1 Curve")
# Out:
# Displaying Training Metrics...
# Displaying Confusion Matrix...
# Displaying  F1 Curve...

# %%
import yaml
import os

# ==========================================
# DYNAMIC CONFIGURATION SETUP
# ==========================================
# This script generates a session-specific YAML file. 
# It ensures the model can find the dataset regardless of the platform/environment.

# Path where the YAML file will be stored in the current session
DATA_CFG = "/kaggle/working/temp_config.yaml"

# Define the dataset structure and class names
config = {
    "path": "/kaggle/input/dl-project/split_data", # Root folder for the dataset
    "train": "train/images",                      # Sub-path for training images
    "val": "val/images",                          # Sub-path for validation images
    "nc": 7,                                      # Number of classes
    
    "names": [
        "tear_crack",       # ID 0
        "scratch",          # ID 1
        "shattered_glass",  # ID 2
        "missing_part",     # ID 3
        "puncture",         # ID 4
        "dent",             # ID 5
        "broken_light"      # ID 6
    ]
}

# Write the configuration to a YAML file in the working directory
with open(DATA_CFG, "w") as f:
    yaml.dump(config, f)

print(f"Session-specific config saved to: {DATA_CFG}")
# Out:
# ✅ Session-specific config saved to: /kaggle/working/temp_config.yaml

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.241-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.241-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.1 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.241 ultralytics-thop-2.0.18

# %%
import os
import random
import numpy as np
from ultralytics import YOLO

# 1. Configuration and Initialization
MODEL_PATH = "/kaggle/input/dl-project/runs/detect/car_damage_7cls_final/weights/best.pt"
CONFIG_PATH = "/kaggle/input/temp-config-yaml/temp_config.yaml"

# Search space boundaries
BOUNDS = {
    'conf': (0.10, 0.40), 
    'iou':  (0.40, 0.70)  
}

# GA Hyperparameters
POPULATION_SIZE = 10
GENERATIONS = 5
MUTATION_RATE = 0.2

model = YOLO(MODEL_PATH)

# 2. Genetic Algorithm Functions
def get_fitness(individual):
    """Objective Function: Evaluates mAP score for given Conf and IoU."""
    conf, iou = individual
    metrics = model.val(data=CONFIG_PATH, split="val", conf=conf, iou=iou, verbose=False, plots=False)
    return metrics.box.map50

def create_individual():
    """Creates a random chromosome (individual)."""
    return [random.uniform(BOUNDS['conf'][0], BOUNDS['conf'][1]), 
            random.uniform(BOUNDS['iou'][0], BOUNDS['iou'][1])]

def crossover(parent1, parent2):
    """Crossover: Produces offspring from two parents."""
    return [parent1[0], parent2[1]], [parent2[0], parent1[1]]

def mutate(individual):
    """Mutation: Randomly alters genes to maintain diversity."""
    for i in range(len(individual)):
        if random.random() < MUTATION_RATE:
            key = 'conf' if i == 0 else 'iou'
            individual[i] = random.uniform(BOUNDS[key][0], BOUNDS[key][1])
    return individual

# 3. Evolutionary Process
print("Starting Genetic Algorithm Optimization...")
population = [create_individual() for _ in range(POPULATION_SIZE)]
best_solution, best_score = None, 0

for gen in range(GENERATIONS):
    print(f"Processing Generation {gen+1}/{GENERATIONS}...")
    
    scored_population = []
    for ind in population:
        score = get_fitness(ind)
        scored_population.append((ind, score))
        if score > best_score:
            best_score, best_solution = score, ind
            print(f"New Best Found: Score {score:.4f} (Conf={ind[0]:.3f}, IoU={ind[1]:.3f})")
    
    scored_population.sort(key=lambda x: x[1], reverse=True)
    top_half = [x[0] for x in scored_population[:POPULATION_SIZE//2]]
    
    new_population = []
    while len(new_population) < POPULATION_SIZE:
        p1, p2 = random.choice(top_half), random.choice(top_half)
        c1, c2 = crossover(p1, p2)
        new_population.extend([mutate(c1), mutate(c2)])
    population = new_population[:POPULATION_SIZE]

print("\nOptimization Complete")
print(f"Optimal Confidence: {best_solution[0]:.4f}")
print(f"Optimal IoU: {best_solution[1]:.4f}")
print(f"Maximized mAP: {best_score:.4f}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Starting Genetic Algorithm Optimization...
# Processing Generation 1/5...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 25.5MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 57.7±10.8 MB/s, size: 193.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 339.0it/s 6.9s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.8it/s 21.5s0.1s
#                    all       2322       6030      0.648      0.437      0.543      0.379
# Speed: 0.6ms preprocess, 6.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# New Best Found: Score 0.5429 (Conf=0.344, IoU=0.493)
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 303.3±78.4 MB/s, size: 218.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 7.0it/s 20.8s0.1s
#                    all       2322       6030      0.555      0.494      0.531      0.365
# Speed: 0.6ms preprocess, 6.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 157.7±103.1 MB/s, size: 123.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.8it/s 21.4s0.2s
#                    all       2322       6030       0.57      0.485      0.513      0.344
# Speed: 0.6ms preprocess, 6.6ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 242.0±108.4 MB/s, size: 179.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.6it/s 22.0s0.2s
#                    all       2322       6030      0.569      0.485      0.514      0.346
# Speed: 0.6ms preprocess, 6.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 349.8±168.8 MB/s, size: 233.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 927.8it/s 2.5s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.4it/s 23.0s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 282.7±59.2 MB/s, size: 187.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.2Kit/s 2.0s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.7s0.2s
#                    all       2322       6030      0.565      0.493      0.533      0.363
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 176.7±92.4 MB/s, size: 146.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.2s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.568      0.492      0.534      0.365
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 197.3±59.3 MB/s, size: 136.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 936.1it/s 2.5s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030      0.579      0.489      0.525      0.352
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 219.4±106.2 MB/s, size: 157.4 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.8s0.2s
#                    all       2322       6030      0.579       0.49      0.521      0.347
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 194.9±111.5 MB/s, size: 117.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.2Kit/s 2.0s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.559      0.494      0.531      0.364
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Processing Generation 2/5...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 348.2±139.2 MB/s, size: 202.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030      0.571      0.493      0.536      0.366
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 275.3±75.3 MB/s, size: 171.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.2Kit/s 2.0s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030      0.643      0.438      0.541      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 186.5±19.3 MB/s, size: 134.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.365
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 267.5±97.2 MB/s, size: 172.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030       0.57      0.491      0.532      0.362
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 254.1±137.4 MB/s, size: 151.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 249.9±44.3 MB/s, size: 150.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 237.7±55.8 MB/s, size: 204.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 988.5it/s 2.4s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 255.2±110.7 MB/s, size: 185.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.8s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 253.9±69.7 MB/s, size: 158.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.571      0.488      0.523      0.354
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 200.9±106.5 MB/s, size: 145.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Processing Generation 3/5...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 263.1±171.4 MB/s, size: 169.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.7s0.2s
#                    all       2322       6030       0.57      0.491      0.532      0.362
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 242.2±107.2 MB/s, size: 179.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 813.8it/s 2.9s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.9s0.2s
#                    all       2322       6030       0.57      0.491      0.532      0.362
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 254.3±97.3 MB/s, size: 162.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.9s0.2s
#                    all       2322       6030      0.577      0.491      0.534      0.362
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 263.9±158.5 MB/s, size: 194.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.365
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 282.8±75.0 MB/s, size: 178.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030       0.65      0.436      0.543      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# New Best Found: Score 0.5431 (Conf=0.344, IoU=0.408)
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 200.2±65.4 MB/s, size: 112.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.8s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 236.5±84.8 MB/s, size: 169.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 995.4it/s 2.3s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 182.6±61.7 MB/s, size: 107.4 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s0.0ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.643      0.438      0.541      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 270.3±158.3 MB/s, size: 174.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.7s0.2s
#                    all       2322       6030       0.57      0.492      0.532      0.362
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 274.3±64.9 MB/s, size: 166.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.568      0.492      0.534      0.365
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Processing Generation 4/5...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 190.9±79.8 MB/s, size: 110.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 271.6±88.7 MB/s, size: 164.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.7s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 248.0±115.1 MB/s, size: 151.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.577      0.491      0.538      0.367
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 330.5±69.5 MB/s, size: 237.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 990.2it/s 2.3s.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030      0.597      0.466      0.536      0.372
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 211.9±67.1 MB/s, size: 130.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.2Kit/s 2.0s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.8s0.2s
#                    all       2322       6030      0.577      0.491      0.538      0.367
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 204.0±59.0 MB/s, size: 156.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.576      0.488      0.536      0.368
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 258.3±118.2 MB/s, size: 150.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 310.9±51.2 MB/s, size: 177.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 989.8it/s 2.3s.0ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 303.3±170.8 MB/s, size: 217.6 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 918.6it/s 2.5s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030       0.65      0.436      0.543      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 200.4±114.0 MB/s, size: 144.7 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 923.3it/s 2.5s0.2s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030      0.645      0.438      0.542      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Processing Generation 5/5...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 194.8±64.3 MB/s, size: 131.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 863.4it/s 2.7s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.589      0.485       0.54      0.369
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 239.5±81.9 MB/s, size: 143.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030      0.643      0.438      0.541      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 170.8±76.3 MB/s, size: 114.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s<0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030       0.65      0.437      0.543      0.379
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# New Best Found: Score 0.5433 (Conf=0.344, IoU=0.447)
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 252.4±112.2 MB/s, size: 153.6 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030      0.581      0.487      0.538      0.369
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 190.5±82.8 MB/s, size: 134.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 254.8±90.6 MB/s, size: 184.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030      0.587      0.486       0.54      0.369
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 318.6±104.4 MB/s, size: 208.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.2s0.2s
#                    all       2322       6030      0.567      0.493      0.534      0.366
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 253.1±80.7 MB/s, size: 163.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.661      0.425      0.543      0.381
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 235.6±129.6 MB/s, size: 161.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.2s<0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.581      0.487      0.538      0.369
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 180.0±60.2 MB/s, size: 130.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.586      0.483      0.538      0.369
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#
# Optimization Complete
# Optimal Confidence: 0.3444
# Optimal IoU: 0.4474
# Maximized mAP: 0.5433

# %%
from ultralytics import YOLO

# ==========================================
# 1. SETTINGS (GA OPTIMIZED RESULTS)
# ==========================================
# Applying the best values found by the Genetic Algorithm
OPTIMAL_CONF = 0.3605
OPTIMAL_IOU  = 0.4127

# File Paths
MODEL_PATH  = "/kaggle/input/best-pt/best (1).pt"
CONFIG_PATH = "/kaggle/input/temp-config-yaml/temp_config.yaml"

# ==========================================
# 2. VALIDATION REPORT
# ==========================================
print("REPORTING WITH OPTIMIZED PARAMETERS...")
print(f"   - Confidence Threshold: {OPTIMAL_CONF}")
print(f"   - IoU Threshold: {OPTIMAL_IOU}")
print("-" * 60)

# Load the model
model = YOLO(MODEL_PATH)

# Start validation (verbose=True provides per-class metrics)
metrics = model.val(
    data=CONFIG_PATH,
    split='val',           # Using the validation set
    conf=OPTIMAL_CONF,     # Optimized Confidence
    iou=OPTIMAL_IOU,       # Optimized IoU
    verbose=True,          # Show detailed class-wise table
    plots=True             # Generate Confusion Matrix and PR Curves
)

print("-" * 60)
print(f"FINAL mAP@50 Score: {metrics.box.map50:.4f}")
print(f"FINAL Precision   : {metrics.box.mp:.4f}")
print(f"FINAL Recall      : {metrics.box.mr:.4f}")
print("-" * 60)
# Out:
# REPORTING WITH OPTIMIZED PARAMETERS...
#    - Confidence Threshold: 0.3605
#    - IoU Threshold: 0.4127
# ------------------------------------------------------------
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 300.7±115.4 MB/s, size: 180.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 5.8it/s 25.3s0.2s
#                    all       2322       6030      0.658       0.43      0.544       0.38
#             tear_crack        659        963      0.515      0.273      0.382      0.247
#                scratch       1140       2378      0.533      0.257      0.379      0.241
#        shattered_glass        379        396      0.849      0.712      0.817      0.668
#           missing_part        402        448      0.762      0.621      0.696      0.536
#               puncture        317        416      0.645      0.433      0.535      0.357
#                   dent        749        971      0.558      0.237       0.38      0.209
#           broken_light        406        458      0.747      0.476       0.62      0.405
# Speed: 0.7ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val51
# ------------------------------------------------------------
# FINAL mAP@50 Score: 0.5440
# FINAL Precision   : 0.6584
# FINAL Recall      : 0.4297
# ------------------------------------------------------------

# %%
from ultralytics import YOLO
import torch
import numpy as np

# ==========================================
# 1. SETTINGS
# ==========================================
MODEL_PATH = "/kaggle/input/dl-project/runs/detect/car_damage_7cls_final/weights/best.pt"
CONFIG_PATH = "/kaggle/input/temp-config-yaml/temp_config.yaml"

# Values to test for Grid Search
# Standard YOLO uses conf=0.25, iou=0.70. We are searching for better parameters.
conf_values = [0.15, 0.20, 0.25, 0.30] 
iou_values  = [0.45, 0.50, 0.60, 0.70]

# ==========================================
# 2. OPTIMIZATION LOOP
# ==========================================
print("Starting Grid Search Optimization...")
print(f"Total Combinations to Test: {len(conf_values) * len(iou_values)}")

try:
    model = YOLO(MODEL_PATH)
except Exception as e:
    print(f"Error loading model. Check path: {MODEL_PATH}")
    raise e

best_map = 0
best_conf = 0
best_iou = 0
results_log = []

for conf in conf_values:
    for iou in iou_values:
        print(f"Testing -> Conf: {conf}, IoU: {iou} ...", end="")
        
        # Run validation test
        metrics = model.val(
            data=CONFIG_PATH,
            split="val",
            conf=conf,
            iou=iou,
            augment=False, 
            verbose=False,
            plots=False
        )
        
        current_map = metrics.box.map50
        results_log.append((conf, iou, current_map))
        print(f" mAP50: {current_map:.4f}")
        
        # Update best results
        if current_map > best_map:
            best_map = current_map
            best_conf = conf
            best_iou = iou

# ==========================================
# 3. FINAL REPORT (FOR PRESENTATION)
# ==========================================
print("\n" + "="*40)
print("       OPTIMIZATION RESULTS       ")
print("="*40)
print(f"Highest Score (mAP50): {best_map:.4f}")
print(f"Optimal Confidence    : {best_conf}")
print(f"Optimal IoU           : {best_iou}")
print("="*40)

print("\nPerformance Ranking Table:")
print(f"{'Conf':<10} {'IoU':<10} {'mAP50':<10}")
print("-" * 30)
for r in sorted(results_log, key=lambda x: x[2], reverse=True):
    print(f"{r[0]:<10} {r[1]:<10} {r[2]:.4f}")
# Out:
# Starting Grid Search Optimization...
# Total Combinations to Test: 16
# Testing -> Conf: 0.15, IoU: 0.45 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 320.8±131.4 MB/s, size: 174.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.581       0.49       0.53      0.357
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5302
# Testing -> Conf: 0.15, IoU: 0.5 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 194.6±119.5 MB/s, size: 143.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.2s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.0it/s 24.5s0.2s
#                    all       2322       6030       0.58      0.489      0.529      0.357
# Speed: 0.6ms preprocess, 7.8ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5291
# Testing -> Conf: 0.15, IoU: 0.6 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 195.2±64.4 MB/s, size: 136.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030       0.57       0.49      0.526      0.356
# Speed: 0.6ms preprocess, 7.3ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5264
# Testing -> Conf: 0.15, IoU: 0.7 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 176.8±32.6 MB/s, size: 115.5 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 959.0it/s 2.4s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.574      0.476      0.517      0.352
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5175
# Testing -> Conf: 0.2, IoU: 0.45 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 137.3±42.6 MB/s, size: 144.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.0Kit/s 2.3s0.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 24.1s0.2s
#                    all       2322       6030      0.571      0.495      0.536      0.364
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5363
# Testing -> Conf: 0.2, IoU: 0.5 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 160.5±66.3 MB/s, size: 127.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 987.8it/s 2.4s.0ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.6s0.2s
#                    all       2322       6030      0.574      0.492      0.535      0.364
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5350
# Testing -> Conf: 0.2, IoU: 0.6 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 240.5±62.4 MB/s, size: 144.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.1it/s 23.9s0.2s
#                    all       2322       6030      0.565      0.493      0.532      0.363
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5321
# Testing -> Conf: 0.2, IoU: 0.7 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 97.8±81.7 MB/s, size: 176.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 940.9it/s 2.5s.0ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.7s0.2s
#                    all       2322       6030      0.574      0.476      0.524      0.359
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.7ms postprocess per image
#  mAP50: 0.5238
# Testing -> Conf: 0.25, IoU: 0.45 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 309.2±133.3 MB/s, size: 195.4 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.2s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.594      0.481       0.54       0.37
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5403
# Testing -> Conf: 0.25, IoU: 0.5 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 270.0±121.7 MB/s, size: 184.2 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.591      0.482      0.539       0.37
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5394
# Testing -> Conf: 0.25, IoU: 0.6 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 217.0±56.0 MB/s, size: 145.1 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.581      0.484      0.536      0.369
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5364
# Testing -> Conf: 0.25, IoU: 0.7 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 262.1±52.5 MB/s, size: 181.3 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.2Kit/s 2.0s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030       0.56      0.486      0.529      0.365
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5291
# Testing -> Conf: 0.3, IoU: 0.45 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 203.9±103.5 MB/s, size: 179.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.1s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.625      0.457      0.542      0.375
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5418
# Testing -> Conf: 0.3, IoU: 0.5 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 188.1±52.7 MB/s, size: 153.8 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.0s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.5s0.2s
#                    all       2322       6030      0.622      0.458      0.541      0.375
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5411
# Testing -> Conf: 0.3, IoU: 0.6 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 269.0±137.7 MB/s, size: 173.6 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s<0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.3it/s 23.3s0.2s
#                    all       2322       6030      0.614      0.458      0.539      0.374
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5385
# Testing -> Conf: 0.3, IoU: 0.7 ...Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 258.1±89.0 MB/s, size: 194.0 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 992.8it/s 2.3s.1ss
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 6.2it/s 23.4s0.2s
#                    all       2322       6030      0.595       0.46      0.532      0.371
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.6ms postprocess per image
#  mAP50: 0.5318
#
# ========================================
#        OPTIMIZATION RESULTS
# ========================================
# Highest Score (mAP50): 0.5418
# Optimal Confidence    : 0.3
# Optimal IoU           : 0.45
# ========================================
#
# Performance Ranking Table:
# Conf       IoU        mAP50
# ------------------------------
# 0.3        0.45       0.5418
# 0.3        0.5        0.5411
# 0.25       0.45       0.5403
# 0.25       0.5        0.5394
# 0.3        0.6        0.5385
# 0.25       0.6        0.5364
# 0.2        0.45       0.5363
# 0.2        0.5        0.5350
# 0.2        0.6        0.5321
# 0.3        0.7        0.5318
# 0.15       0.45       0.5302
# 0.15       0.5        0.5291
# 0.25       0.7        0.5291
# 0.15       0.6        0.5264
# 0.2        0.7        0.5238
# 0.15       0.7        0.5175

# %%
from ultralytics import YOLO

# ==========================================
# 1. SETTINGS (GA + TTA)
# ==========================================
# Using optimal values found via Genetic Algorithm
OPTIMAL_CONF = 0.3605
OPTIMAL_IOU  = 0.4127

MODEL_PATH  = "/kaggle/input/dl-project/runs/detect/car_damage_7cls_final/weights/best.pt"
CONFIG_PATH = "/kaggle/input/temp-config-yaml/temp_config.yaml"

# ==========================================
# 2. FINAL VALIDATION - TTA ENABLED
# ==========================================
print("MEASURING FINAL PERFORMANCE (GA + TTA)...")
print(f"   - Confidence Threshold: {OPTIMAL_CONF}")
print(f"   - IoU Threshold       : {OPTIMAL_IOU}")
print(f"   - TTA (Augment)       : ENABLED")
print("-" * 60)

model = YOLO(MODEL_PATH)

# Measuring with TTA (augment=True)
metrics = model.val(
    data=CONFIG_PATH,
    split='val',
    conf=OPTIMAL_CONF,
    iou=OPTIMAL_IOU,
    augment=True,      # This enables Test Time Augmentation
    verbose=True,
    plots=False        # Disabled plots for faster processing
)

print("-" * 60)
print(f"Final TTA-enhanced mAP@50 : {metrics.box.map50:.4f}")
print(f"Final TTA-enhanced Precision: {metrics.box.mp:.4f}")
print(f"Final TTA-enhanced Recall   : {metrics.box.mr:.4f}")
print("-" * 60)
# Out:
# MEASURING FINAL PERFORMANCE (GA + TTA)...
#    - Confidence Threshold: 0.3605
#    - IoU Threshold       : 0.4127
#    - TTA (Augment)       : ENABLED
# ------------------------------------------------------------
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 285.3±92.8 MB/s, size: 171.9 KB)
# val: Scanning /kaggle/input/dl-project/split_data/val/labels... 2322 images, 0 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 2324/2324 1.1Kit/s 2.1s0.0s
# val: /kaggle/input/dl-project/split_data/val/images/24032020_094730image64439.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# val: /kaggle/input/dl-project/split_data/val/images/24032020_140438image435324.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# WARNING ⚠️ val: Cache directory /kaggle/input/dl-project/split_data/val is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 146/146 2.9it/s 50.3s0.4ss
#                    all       2322       6030      0.611      0.479      0.555      0.388
#             tear_crack        659        963       0.49      0.356      0.413      0.281
#                scratch       1140       2378      0.485      0.296      0.379      0.241
#        shattered_glass        379        396      0.844       0.75      0.836      0.686
#           missing_part        402        448      0.699      0.643      0.709      0.557
#               puncture        317        416      0.602      0.476      0.546      0.362
#                   dent        749        971       0.48      0.298      0.382      0.197
#           broken_light        406        458      0.678      0.537      0.619      0.394
# Speed: 0.6ms preprocess, 19.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# ------------------------------------------------------------
# Final TTA-enhanced mAP@50 : 0.5547
# Final TTA-enhanced Precision: 0.6110
# Final TTA-enhanced Recall   : 0.4794
# ------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

# Updated Data (Baseline: 0.4709)
labels = ['Baseline', 'Optimized (GA)', 'Final (GA+TTA)']
map_scores = [0.4709, 0.5440, 0.5547]
precision_scores = [0.5735, 0.6584, 0.6110]
recall_scores = [0.4758, 0.4297, 0.4794]

x = np.arange(len(labels))  # Label locations
width = 0.25  # Width of the bars

fig, ax = plt.subplots(figsize=(12, 7))

# Creating the bars
rects1 = ax.bar(x - width, map_scores, width, label='mAP@50', color='#2ecc71', edgecolor='black', alpha=0.8)
rects2 = ax.bar(x, precision_scores, width, label='Precision', color='#3498db', edgecolor='black', alpha=0.8)
rects3 = ax.bar(x + width, recall_scores, width, label='Recall', color='#e74c3c', edgecolor='black', alpha=0.8)

# Axis and Title Settings
ax.set_ylabel('Scores', fontweight='bold', fontsize=12)
ax.set_title('Model Performance Evolution: Baseline vs. Optimized vs. Final', fontsize=16, fontweight='bold', pad=20)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=11, fontweight='bold')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10)

# Function to add value labels on top of bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 5), textcoords="offset points",
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

# Aesthetic improvements
plt.ylim(0.35, 0.75) 
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

# Save the plot
plt.savefig('performance_comparison_final.png', dpi=300)
plt.show()

# %%
import os
import glob
import random

# ==========================================================
# ALL IN-PERSON DATA (COMPLETE PREDICTION)
# ==========================================================
print("\n" + "="*50)
print("SCENARIO A: IN-PERSON (FULL DIRECTORY + TTA)")
print("="*50)

# Direct path to the In-Person dataset in Kaggle environment
DIRECT_IN_PERSON_PATH = "/kaggle/input/in-person-test-data/In_Person"

if os.path.exists(DIRECT_IN_PERSON_PATH):
    # Fetch and sort every valid image file to ensure consistent testing
    in_person_imgs = sorted(glob.glob(os.path.join(DIRECT_IN_PERSON_PATH, "*.*")))
    in_person_imgs = [x for x in in_person_imgs if x.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
    
    print(f"DEBUG: Found {len(in_person_imgs)} images at {DIRECT_IN_PERSON_PATH}")
    
    if len(in_person_imgs) > 0:
        print("Status: Starting Full Inference for In-Person images...")
        # Running the full local dataset validates real-world reliability without selection bias
        model.predict(
            source=in_person_imgs,
            save=True,               # Save images with visualized bounding boxes
            conf=BEST_CONF,          # Applying GA-Optimized Confidence threshold (e.g., 0.36)
            iou=BEST_IOU,            # Applying GA-Optimized IoU threshold (e.g., 0.41)
            augment=True,            # Enable Test Time Augmentation (TTA) for multi-angle robustness
            device=device,
            project=OUTPUT_BASE,
            name="final_in_person_complete",
            exist_ok=True,
            verbose=True             # Enabling verbose to monitor per-image latency and results
        )
    else:
        print("WARNING: No valid images found in In-Person directory!")
else:
    print(f"ERROR: Directory NOT found: {DIRECT_IN_PERSON_PATH}")

# ==========================================================
# BING DATA (RANDOM 200 SAMPLES)
# ==========================================================
print("\n" + "="*50)
print("SCENARIO B: BING DATA (200 RANDOM SAMPLES + TTA)")
print("="*50)

# Direct path to the Bing dataset in Kaggle environment
DIRECT_BING_PATH = "/kaggle/input/dataset-bing/dataset_raw_bing"

if os.path.exists(DIRECT_BING_PATH):
    # Perform a recursive search for all images across nested directories
    all_bing = glob.glob(os.path.join(DIRECT_BING_PATH, "**", "*.*"), recursive=True)
    all_bing = [x for x in all_bing if x.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    print(f"DEBUG: Found {len(all_bing)} total images at {DIRECT_BING_PATH}")
    
    if len(all_bing) > 0:
        # Sampling 200 images provides a diverse web-data validation set while optimizing compute time
        sample_size = min(200, len(all_bing))
        selected_bing = random.sample(all_bing, sample_size)
        print(f"Status: Starting Inference for {sample_size} random Bing images...")
        
        model.predict(
            source=selected_bing,
            save=True,
            conf=BEST_CONF,
            iou=BEST_IOU,
            augment=True,
            device=device,
            project=OUTPUT_BASE,
            name="final_bing_optimized_200", 
            exist_ok=True,
            verbose=True 
        )
        print("Bing 200 Samples Optimized Inference Complete.")
    else:
        print("WARNING: No valid images found in Bing directory!")
else:
    print(f"ERROR: Directory NOT found: {DIRECT_BING_PATH}")
# Out:
# ==================================================
# SCENARIO A: IN-PERSON (FULL DIRECTORY + TTA)
# ==================================================
# DEBUG: Found 24 images at /kaggle/input/in-person-test-data/In_Person
# Status: Starting Full Inference for In-Person images...
#
# 0: 640x640 1 missing_part, 23.9ms
# 1: 640x640 1 missing_part, 23.9ms
# 2: 640x640 1 missing_part, 23.9ms
# 3: 640x640 1 missing_part, 23.9ms
# 4: 640x640 1 missing_part, 23.9ms
# 5: 640x640 1 scratch, 1 missing_part, 1 dent, 23.9ms
# 6: 640x640 1 missing_part, 1 broken_light, 23.9ms
# 7: 640x640 1 missing_part, 23.9ms
# 8: 640x640 2 scratchs, 1 missing_part, 23.9ms
# 9: 640x640 1 tear_crack, 23.9ms
# 10: 640x640 4 tear_cracks, 1 puncture, 1 dent, 1 broken_light, 23.9ms
# 11: 640x640 1 missing_part, 23.9ms
# 12: 640x640 (no detections), 23.9ms
# 13: 640x640 1 missing_part, 23.9ms
# 14: 640x640 2 missing_parts, 1 dent, 23.9ms
# 15: 640x640 1 tear_crack, 1 dent, 23.9ms
# 16: 640x640 1 scratch, 1 missing_part, 23.9ms
# 17: 640x640 1 scratch, 1 dent, 23.9ms
# 18: 640x640 1 broken_light, 23.9ms
# 19: 640x640 1 tear_crack, 1 missing_part, 23.9ms
# 20: 640x640 1 tear_crack, 23.9ms
# 21: 640x640 1 missing_part, 23.9ms
# 22: 640x640 1 scratch, 2 missing_parts, 23.9ms
# 23: 640x640 1 scratch, 1 missing_part, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /kaggle/working/runs/detect/final_in_person_complete
#
# ==================================================
# SCENARIO B: BING DATA (200 RANDOM SAMPLES + TTA)
# ==================================================
# DEBUG: Found 1244 total images at /kaggle/input/dataset-bing/dataset_raw_bing
# Status: Starting Inference for 200 random Bing images...
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 0: 640x640 1 missing_part, 24.5ms
# 1: 640x640 1 tear_crack, 1 scratch, 1 dent, 24.5ms
# 2: 640x640 1 missing_part, 24.5ms
# 3: 640x640 1 tear_crack, 1 missing_part, 1 dent, 24.5ms
# 4: 640x640 1 tear_crack, 1 missing_part, 1 dent, 24.5ms
# 5: 640x640 1 scratch, 1 dent, 24.5ms
# 6: 640x640 1 missing_part, 2 dents, 24.5ms
# 7: 640x640 2 tear_cracks, 1 broken_light, 24.5ms
# 8: 640x640 1 shattered_glass, 24.5ms
# 9: 640x640 1 missing_part, 24.5ms
# 10: 640x640 1 missing_part, 24.5ms
# 11: 640x640 2 dents, 24.5ms
# 12: 640x640 1 missing_part, 24.5ms
# 13: 640x640 1 missing_part, 24.5ms
# 14: 640x640 1 shattered_glass, 24.5ms
# 15: 640x640 2 scratchs, 24.5ms
# 16: 640x640 2 scratchs, 1 dent, 24.5ms
# 17: 640x640 1 scratch, 24.5ms
# 18: 640x640 2 scratchs, 1 missing_part, 24.5ms
# 19: 640x640 2 dents, 24.5ms
# 20: 640x640 1 dent, 24.5ms
# 21: 640x640 1 missing_part, 1 dent, 24.5ms
# 22: 640x640 1 missing_part, 24.5ms
# 23: 640x640 1 broken_light, 24.5ms
# 24: 640x640 1 dent, 24.5ms
# 25: 640x640 1 shattered_glass, 24.5ms
# 26: 640x640 2 missing_parts, 2 dents, 24.5ms
# 27: 640x640 1 dent, 24.5ms
# 28: 640x640 1 missing_part, 2 dents, 24.5ms
# 29: 640x640 1 dent, 1 broken_light, 24.5ms
# 30: 640x640 1 dent, 24.5ms
# 31: 640x640 1 shattered_glass, 1 missing_part, 2 dents, 24.5ms
# 32: 640x640 1 missing_part, 24.5ms
# 33: 640x640 1 scratch, 1 dent, 24.5ms
# 34: 640x640 1 dent, 1 broken_light, 24.5ms
# 35: 640x640 1 missing_part, 24.5ms
# 36: 640x640 (no detections), 24.5ms
# 37: 640x640 2 tear_cracks, 1 scratch, 2 dents, 24.5ms
# 38: 640x640 1 missing_part, 24.5ms
# 39: 640x640 1 missing_part, 24.5ms
# 40: 640x640 1 missing_part, 24.5ms
# 41: 640x640 1 missing_part, 24.5ms
# 42: 640x640 1 broken_light, 24.5ms
# 43: 640x640 1 scratch, 3 dents, 1 broken_light, 24.5ms
# 44: 640x640 1 shattered_glass, 1 missing_part, 1 dent, 24.5ms
# 45: 640x640 1 scratch, 24.5ms
# 46: 640x640 1 tear_crack, 24.5ms
# 47: 640x640 1 broken_light, 24.5ms
# 48: 640x640 1 shattered_glass, 24.5ms
# 49: 640x640 1 puncture, 24.5ms
# 50: 640x640 1 tear_crack, 1 scratch, 1 broken_light, 24.5ms
# 51: 640x640 1 missing_part, 24.5ms
# 52: 640x640 1 shattered_glass, 24.5ms
# 53: 640x640 4 scratchs, 1 dent, 24.5ms
# 54: 640x640 1 puncture, 24.5ms
# 55: 640x640 1 dent, 24.5ms
# 56: 640x640 1 missing_part, 24.5ms
# 57: 640x640 1 missing_part, 24.5ms
# 58: 640x640 2 scratchs, 24.5ms
# 59: 640x640 1 missing_part, 2 dents, 24.5ms
# 60: 640x640 1 shattered_glass, 24.5ms
# 61: 640x640 1 tear_crack, 2 shattered_glasss, 1 dent, 24.5ms
# 62: 640x640 1 shattered_glass, 24.5ms
# 63: 640x640 1 dent, 24.5ms
# 64: 640x640 1 tear_crack, 2 shattered_glasss, 2 dents, 1 broken_light, 24.5ms
# 65: 640x640 1 shattered_glass, 1 missing_part, 1 puncture, 24.5ms
# 66: 640x640 1 tear_crack, 1 missing_part, 1 dent, 24.5ms
# 67: 640x640 1 scratch, 24.5ms
# 68: 640x640 1 missing_part, 24.5ms
# 69: 640x640 1 missing_part, 24.5ms
# 70: 640x640 1 scratch, 1 dent, 2 broken_lights, 24.5ms
# 71: 640x640 1 scratch, 1 dent, 24.5ms
# 72: 640x640 2 scratchs, 24.5ms
# 73: 640x640 2 tear_cracks, 1 missing_part, 24.5ms
# 74: 640x640 (no detections), 24.5ms
# 75: 640x640 1 scratch, 1 shattered_glass, 24.5ms
# 76: 640x640 1 shattered_glass, 24.5ms
# 77: 640x640 1 tear_crack, 1 broken_light, 24.5ms
# 78: 640x640 2 tear_cracks, 1 scratch, 2 dents, 1 broken_light, 24.5ms
# 79: 640x640 1 missing_part, 24.5ms
# 80: 640x640 1 shattered_glass, 24.5ms
# 81: 640x640 1 missing_part, 24.5ms
# 82: 640x640 1 scratch, 24.5ms
# 83: 640x640 2 shattered_glasss, 2 missing_parts, 24.5ms
# 84: 640x640 1 shattered_glass, 3 dents, 24.5ms
# 85: 640x640 1 missing_part, 24.5ms
# 86: 640x640 1 tear_crack, 1 scratch, 24.5ms
# 87: 640x640 2 scratchs, 1 broken_light, 24.5ms
# 88: 640x640 1 missing_part, 24.5ms
# 89: 640x640 1 shattered_glass, 1 missing_part, 24.5ms
# 90: 640x640 (no detections), 24.5ms
# 91: 640x640 1 dent, 24.5ms
# 92: 640x640 2 shattered_glasss, 24.5ms
# 93: 640x640 (no detections), 24.5ms
# 94: 640x640 1 scratch, 2 dents, 24.5ms
# 95: 640x640 1 dent, 24.5ms
# 96: 640x640 1 shattered_glass, 24.5ms
# 97: 640x640 1 missing_part, 24.5ms
# 98: 640x640 1 missing_part, 24.5ms
# 99: 640x640 2 scratchs, 1 broken_light, 24.5ms
# 100: 640x640 1 missing_part, 24.5ms
# 101: 640x640 1 tear_crack, 2 missing_parts, 1 puncture, 3 dents, 24.5ms
# 102: 640x640 1 shattered_glass, 2 missing_parts, 24.5ms
# 103: 640x640 1 shattered_glass, 1 missing_part, 24.5ms
# 104: 640x640 1 missing_part, 1 dent, 1 broken_light, 24.5ms
# 105: 640x640 1 scratch, 1 dent, 24.5ms
# 106: 640x640 1 tear_crack, 1 scratch, 24.5ms
# 107: 640x640 1 shattered_glass, 24.5ms
# 108: 640x640 1 dent, 24.5ms
# 109: 640x640 2 tear_cracks, 1 scratch, 2 dents, 1 broken_light, 24.5ms
# 110: 640x640 1 shattered_glass, 1 dent, 24.5ms
# 111: 640x640 1 shattered_glass, 24.5ms
# 112: 640x640 (no detections), 24.5ms
# 113: 640x640 1 shattered_glass, 24.5ms
# 114: 640x640 1 scratch, 1 dent, 24.5ms
# 115: 640x640 (no detections), 24.5ms
# 116: 640x640 1 tear_crack, 24.5ms
# 117: 640x640 (no detections), 24.5ms
# 118: 640x640 2 shattered_glasss, 24.5ms
# 119: 640x640 2 tear_cracks, 1 missing_part, 2 dents, 24.5ms
# 120: 640x640 1 missing_part, 24.5ms
# 121: 640x640 2 broken_lights, 24.5ms
# 122: 640x640 1 missing_part, 24.5ms
# 123: 640x640 1 dent, 24.5ms
# 124: 640x640 2 scratchs, 24.5ms
# 125: 640x640 1 shattered_glass, 24.5ms
# 126: 640x640 1 dent, 24.5ms
# 127: 640x640 3 shattered_glasss, 1 broken_light, 24.5ms
# 128: 640x640 2 tear_cracks, 2 scratchs, 1 broken_light, 24.5ms
# 129: 640x640 1 scratch, 1 broken_light, 24.5ms
# 130: 640x640 1 missing_part, 24.5ms
# 131: 640x640 1 missing_part, 2 dents, 24.5ms
# 132: 640x640 1 scratch, 2 missing_parts, 2 dents, 24.5ms
# 133: 640x640 2 tear_cracks, 1 scratch, 2 missing_parts, 24.5ms
# 134: 640x640 1 scratch, 24.5ms
# 135: 640x640 1 scratch, 24.5ms
# 136: 640x640 1 dent, 24.5ms
# 137: 640x640 2 missing_parts, 3 dents, 24.5ms
# 138: 640x640 (no detections), 24.5ms
# 139: 640x640 1 scratch, 24.5ms
# 140: 640x640 1 dent, 24.5ms
# 141: 640x640 1 missing_part, 24.5ms
# 142: 640x640 1 shattered_glass, 24.5ms
# 143: 640x640 1 tear_crack, 1 dent, 24.5ms
# 144: 640x640 1 missing_part, 24.5ms
# 145: 640x640 1 scratch, 24.5ms
# 146: 640x640 1 missing_part, 24.5ms
# 147: 640x640 1 tear_crack, 1 broken_light, 24.5ms
# 148: 640x640 1 shattered_glass, 24.5ms
# 149: 640x640 1 shattered_glass, 1 missing_part, 24.5ms
# 150: 640x640 1 missing_part, 3 dents, 24.5ms
# 151: 640x640 1 dent, 24.5ms
# 152: 640x640 2 missing_parts, 1 dent, 24.5ms
# 153: 640x640 1 dent, 24.5ms
# 154: 640x640 1 shattered_glass, 24.5ms
# 155: 640x640 1 missing_part, 24.5ms
# 156: 640x640 1 shattered_glass, 24.5ms
# 157: 640x640 3 dents, 24.5ms
# 158: 640x640 1 shattered_glass, 24.5ms
# 159: 640x640 1 missing_part, 24.5ms
# 160: 640x640 1 tear_crack, 1 scratch, 24.5ms
# 161: 640x640 1 scratch, 1 dent, 24.5ms
# 162: 640x640 2 tear_cracks, 2 missing_parts, 2 dents, 24.5ms
# 163: 640x640 1 missing_part, 24.5ms
# 164: 640x640 1 dent, 24.5ms
# 165: 640x640 1 dent, 24.5ms
# 166: 640x640 1 dent, 24.5ms
# 167: 640x640 1 tear_crack, 1 shattered_glass, 24.5ms
# 168: 640x640 1 broken_light, 24.5ms
# 169: 640x640 2 scratchs, 24.5ms
# 170: 640x640 1 dent, 24.5ms
# 171: 640x640 2 scratchs, 24.5ms
# 172: 640x640 1 scratch, 2 missing_parts, 24.5ms
# 173: 640x640 4 tear_cracks, 1 dent, 1 broken_light, 24.5ms
# 174: 640x640 1 scratch, 1 puncture, 1 dent, 24.5ms
# 175: 640x640 1 tear_crack, 1 missing_part, 24.5ms
# 176: 640x640 1 shattered_glass, 24.5ms
# 177: 640x640 2 dents, 24.5ms
# 178: 640x640 1 shattered_glass, 24.5ms
# 179: 640x640 1 dent, 24.5ms
# 180: 640x640 4 tear_cracks, 3 dents, 1 broken_light, 24.5ms
# 181: 640x640 1 missing_part, 24.5ms
# 182: 640x640 2 missing_parts, 24.5ms
# 183: 640x640 1 missing_part, 2 dents, 24.5ms
# 184: 640x640 (no detections), 24.5ms
# 185: 640x640 1 shattered_glass, 24.5ms
# 186: 640x640 (no detections), 24.5ms
# 187: 640x640 1 scratch, 24.5ms
# 188: 640x640 1 scratch, 24.5ms
# 189: 640x640 2 shattered_glasss, 1 dent, 24.5ms
# 190: 640x640 1 tear_crack, 2 dents, 24.5ms
# 191: 640x640 (no detections), 24.5ms
# 192: 640x640 1 shattered_glass, 1 dent, 24.5ms
# 193: 640x640 1 missing_part, 24.5ms
# 194: 640x640 2 shattered_glasss, 2 dents, 24.5ms
# 195: 640x640 1 tear_crack, 2 dents, 24.5ms
# 196: 640x640 1 shattered_glass, 24.5ms
# 197: 640x640 (no detections), 24.5ms
# 198: 640x640 2 dents, 24.5ms
# 199: 640x640 2 scratchs, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /kaggle/working/runs/detect/final_bing_optimized_200
# Bing 200 Samples Optimized Inference Complete.
